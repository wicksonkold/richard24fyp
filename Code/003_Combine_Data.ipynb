# %%
import pandas as pd
import os

def concatenate_excel_files(folder_path):
    """
    Concatenates all Excel files in a given folder into a single DataFrame.
    Assumes that all Excel files have the same column structure.

    :param folder_path: str, the path to the folder containing Excel files.
    :return: DataFrame, the concatenated DataFrame containing all data.
    """
    # List all Excel files in the directory
    excel_files = [file for file in os.listdir(folder_path) if file.endswith('.xlsx')]

    # Initialize an empty list to store the DataFrames
    df_list = []

    # Loop through the list of Excel files
    for file in excel_files:
        # Construct the full file path
        file_path = os.path.join(folder_path, file)
        # Read the Excel file into a DataFrame
        df = pd.read_excel(file_path)
        # Append the DataFrame to the list
        df_list.append(df)

    # Concatenate all DataFrames in the list into one
    combined_df = pd.concat(df_list, ignore_index=True)
    
    return combined_df

def check_values_in_column(df, column_name):
    """
    Checks if the cells in the specified column of the DataFrame have values.
    Adds a new column to the DataFrame to store the boolean result.

    :param df: DataFrame, the DataFrame to check.
    :param column_name: str, the name of the column to check for values.
    :return: DataFrame, the DataFrame with the new boolean result column added.
    """
    # Define the new column name
    new_column_name = f'BOOL {column_name}'

    # Check if each cell in the specified column has a value and store the result in the new column
    df[new_column_name] = df[column_name].notnull()

    return df

# %%
# Define the path where the Excel files are located
folder_path_1 = 'C:\\Users\\User\\Desktop\\Final Year Project\\Code\\Processed_CX\\02_Transform_Data_Frame\\Result_1'
folder_path_2 = 'C:\\Users\\User\\Desktop\\Final Year Project\\Code\\Processed_CX\\02_Transform_Data_Frame\\Result_2'
folder_path_3 = 'C:\\Users\\User\\Desktop\\Final Year Project\\Code\\Processed_CX\\02_Transform_Data_Frame\\Result_3'

check_AOA_I = 'Angle of Attack (Indicated) (LH or only) (deg)'

# %%
combined_df_1 = concatenate_excel_files(folder_path_1)
combined_df_1['predictive or reactive wind shear warning'] = True
combined_df_1 = check_values_in_column(combined_df_1, check_AOA_I)
combined_df_1['label'] = True
combined_df_1
# Out:
#         Offset  UTC time  Airframe  Corrected Latitude (deg)  \
# 0      59652.0  21:24:33       124                 22.272130
# 1      59653.0  21:24:34       124                 22.272365
# 2      59654.0  21:24:35       124                 22.272597
# 3      59655.0  21:24:36       124                 22.272829
# 4      59656.0  21:24:37       124                 22.273049
# ...        ...       ...       ...                       ...
# 10697  11119.0  21:48:22        46                 22.379940
# 10698  11120.0  21:48:22        46                 22.380659
# 10699  11121.0       NaN        46                 22.381379
# 10700  11122.0       NaN        46                 22.382129
# 10701  11123.0  21:48:30        46                 22.382880
#
#        Corrected Longitude (deg)  Heading (true) (deg)  \
# 0                     113.824093             73.448812
# 1                     113.824795             73.975996
# 2                     113.825490             73.624292
# 3                     113.826185             72.921017
# 4                     113.826884             72.745088
# ...                          ...                   ...
# 10697                 114.009234             66.093758
# 10698                 114.010283             64.951180
# 10699                 114.011333             63.105473
# 10700                 114.012371             61.523441
# 10701                 114.013409             60.380863
#
#        Wind Direction (true) (deg)  Wind Speed (knots)  \
# 0                       161.542923               4.000
# 1                        92.109352               6.000
# 2                        98.789040               8.000
# 3                       123.222626               5.000
# 4                       112.939423               2.000
# ...                            ...                 ...
# 10697                   159.609375              50.500
# 10698                   159.609375              46.250
# 10699                   155.390625              42.875
# 10700                   161.718750              42.500
# 10701                   163.828125              44.625
#
#        Airspeed (calibrated; 1 or Only) (knots)  Baro-Corrected Altitude (ft)  \
# 0                                       149.000                        1444.0
# 1                                       149.000                        1440.0
# 2                                       149.500                        1424.0
# 3                                       144.000                        1412.0
# 4                                       145.000                        1400.0
# ...                                         ...                           ...
# 10697                                   231.875                        4964.0
# 10698                                   230.125                        4976.0
# 10699                                   231.375                        4980.0
# 10700                                   232.125                        4984.0
# 10701                                   230.625                        4988.0
#
#        ...  Angle of Attack (Corrected) (LH or only) (deg)  \
# 0      ...                                        5.625001
# 1      ...                                        5.273439
# 2      ...                                        2.285157
# 3      ...                                        5.273439
# 4      ...                                        5.800783
# ...    ...                                             ...
# 10697  ...                                        3.471679
# 10698  ...                                        4.658203
# 10699  ...                                        3.867187
# 10700  ...                                        3.164062
# 10701  ...                                        3.471679
#
#        Pitch Attitude (Capt or Only) (deg)  Airport and Runway (Landing)  \
# 0                                 1.582032                      VHHH 07R
# 1                                 2.109375                      VHHH 07R
# 2                                 1.933594                      VHHH 07R
# 3                                 1.582032                      VHHH 07R
# 4                                 1.582032                      VHHH 07R
# ...                                    ...                           ...
# 10697                             4.570312                      VHHH 07L
# 10698                             3.867188                      VHHH 07L
# 10699                             3.515625                      VHHH 07L
# 10700                             3.515625                      VHHH 07L
# 10701                             3.515625                      VHHH 07L
#
#        Date-Time at Touchdown     Filename  adjusted landing time  \
# 0         2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:23
# 1         2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:24
# 2         2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:25
# 3         2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:26
# 4         2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:27
# ...                       ...          ...                    ...
# 10697     2018-09-16 22:03:00   973024.csv    2018-09-16 22:02:56
# 10698     2018-09-16 22:03:00   973024.csv    2018-09-16 22:02:57
# 10699     2018-09-16 22:03:00   973024.csv    2018-09-16 22:02:58
# 10700     2018-09-16 22:03:00   973024.csv    2018-09-16 22:02:59
# 10701     2018-09-16 22:03:00   973024.csv    2018-09-16 22:03:00
#
#       Angle of Attack (Best Available) (deg)  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 10697                                    NaN
# 10698                                    NaN
# 10699                                    NaN
# 10700                                    NaN
# 10701                                    NaN
#
#       predictive or reactive wind shear warning  \
# 0                                          True
# 1                                          True
# 2                                          True
# 3                                          True
# 4                                          True
# ...                                         ...
# 10697                                      True
# 10698                                      True
# 10699                                      True
# 10700                                      True
# 10701                                      True
#
#       BOOL Angle of Attack (Indicated) (LH or only) (deg) label
# 0                                                   True   True
# 1                                                   True   True
# 2                                                   True   True
# 3                                                   True   True
# 4                                                   True   True
# ...                                                  ...    ...
# 10697                                               True   True
# 10698                                               True   True
# 10699                                               True   True
# 10700                                               True   True
# 10701                                               True   True
#
# [10702 rows x 24 columns]

# %%
combined_df_2 = concatenate_excel_files(folder_path_2)
combined_df_2['15 knots at the point of GA'] = True
combined_df_2 = check_values_in_column(combined_df_2, check_AOA_I)
combined_df_2['label'] = True
combined_df_2
# Out:
#       Offset UTC time  Airframe  Corrected Latitude (deg)  \
# 0       9388  7:13:55        46                 22.285688
# 1       9389  7:13:56        46                 22.286006
# 2       9390  7:13:57        46                 22.286324
# 3       9391  7:13:58        46                 22.286632
# 4       9392  7:13:59        46                 22.286939
# ...      ...      ...       ...                       ...
# 31423   8781      NaN        57                 22.365787
# 31424   8782      NaN        57                 22.366405
# 31425   8783  7:21:44        57                 22.366981
# 31426   8784  7:21:44        57                 22.367556
# 31427   8785      NaN        57                 22.368148
#
#        Corrected Longitude (deg)  Heading (true) (deg)  \
# 0                     113.821250             72.064819
# 1                     113.822199             72.020874
# 2                     113.823148             71.993408
# 3                     113.824102             72.042847
# 4                     113.825057             72.130737
# ...                          ...                   ...
# 31423                 113.982180             58.886723
# 31424                 113.983219             59.150394
# 31425                 113.984175             59.150394
# 31426                 113.985131             59.062504
# 31427                 113.986104             59.150394
#
#        Wind Direction (true) (deg)  Wind Speed (knots)  \
# 0                       237.656250              27.250
# 1                       238.359375              27.000
# 2                       238.359375              27.000
# 3                       237.656250              26.875
# 4                       236.953125              26.750
# ...                            ...                 ...
# 31423                   206.015625              23.375
# 31424                   208.125000              21.875
# 31425                   211.640625              23.375
# 31426                   210.937500              25.375
# 31427                   211.640625              25.000
#
#        Airspeed (calibrated; 1 or Only) (knots)  Baro-Corrected Altitude (ft)  \
# 0                                      169.0000                        1420.0
# 1                                      168.4375                        1408.0
# 2                                      167.8125                        1384.0
# 3                                      167.8125                        1372.0
# 4                                      167.2500                        1360.0
# ...                                         ...                           ...
# 31423                                  212.5000                        4969.0
# 31424                                  215.2500                        4975.0
# 31425                                  213.5000                        4980.0
# 31426                                  212.0000                        4985.0
# 31427                                  212.8750                        4989.0
#
#        ...  Angle of Attack (Corrected) (LH or only) (deg)  \
# 0      ...                                        0.000000
# 1      ...                                        0.175781
# 2      ...                                        0.483398
# 3      ...                                        0.483398
# 4      ...                                        0.483398
# ...    ...                                             ...
# 31423  ...                                        3.779297
# 31424  ...                                        3.867187
# 31425  ...                                        3.295898
# 31426  ...                                        3.208008
# 31427  ...                                        3.208008
#
#        Pitch Attitude (Capt or Only) (deg)  Airport and Runway (Landing)  \
# 0                                -2.488403                      VHHH 07L
# 1                                -2.499390                      VHHH 07L
# 2                                -2.422485                      VHHH 07L
# 3                                -2.466431                      VHHH 07L
# 4                                -2.603760                      VHHH 07L
# ...                                    ...                           ...
# 31423                             4.570312                      VHHH 07L
# 31424                             4.218750                      VHHH 07L
# 31425                             3.867188                      VHHH 07L
# 31426                             3.515625                      VHHH 07L
# 31427                             3.515625                      VHHH 07L
#
#        Date-Time at Touchdown     Filename  adjusted landing time  \
# 0         2019-08-26 07:35:00  1002183.csv    2019-08-26 07:30:19
# 1         2019-08-26 07:35:00  1002183.csv    2019-08-26 07:30:20
# 2         2019-08-26 07:35:00  1002183.csv    2019-08-26 07:30:21
# 3         2019-08-26 07:35:00  1002183.csv    2019-08-26 07:30:22
# 4         2019-08-26 07:35:00  1002183.csv    2019-08-26 07:30:23
# ...                       ...          ...                    ...
# 31423     2019-08-26 07:39:00   993893.csv    2019-08-26 07:38:56
# 31424     2019-08-26 07:39:00   993893.csv    2019-08-26 07:38:57
# 31425     2019-08-26 07:39:00   993893.csv    2019-08-26 07:38:58
# 31426     2019-08-26 07:39:00   993893.csv    2019-08-26 07:38:59
# 31427     2019-08-26 07:39:00   993893.csv    2019-08-26 07:39:00
#
#       Angle of Attack (Best Available) (deg) 15 knots at the point of GA  \
# 0                                        NaN                        True
# 1                                        NaN                        True
# 2                                        NaN                        True
# 3                                        NaN                        True
# 4                                        NaN                        True
# ...                                      ...                         ...
# 31423                                    NaN                        True
# 31424                                    NaN                        True
# 31425                                    NaN                        True
# 31426                                    NaN                        True
# 31427                                    NaN                        True
#
#       BOOL Angle of Attack (Indicated) (LH or only) (deg) label
# 0                                                   True   True
# 1                                                   True   True
# 2                                                   True   True
# 3                                                   True   True
# 4                                                   True   True
# ...                                                  ...    ...
# 31423                                               True   True
# 31424                                               True   True
# 31425                                               True   True
# 31426                                               True   True
# 31427                                               True   True
#
# [31428 rows x 24 columns]

# %%
combined_df_3 = concatenate_excel_files(folder_path_3)
combined_df_3['15 knots at the point of GA'] = True
combined_df_3 = check_values_in_column(combined_df_3, check_AOA_I)
combined_df_3['label'] = False
combined_df_3
# Out:
#         Offset UTC time  Airframe  Corrected Latitude (deg)  \
# 0       5558.0      NaN        88                 22.286422
# 1       5559.0  6:42:47        88                 22.286659
# 2       5560.0      NaN        88                 22.286897
# 3       5561.0      NaN        88                 22.287134
# 4       5562.0      NaN        88                 22.287371
# ...        ...      ...       ...                       ...
# 712418  9493.0      NaN        46                 22.316359
# 712419  9494.0      NaN        46                 22.316406
# 712420  9495.0  6:14:50        46                 22.316439
# 712421  9496.0  6:14:50        46                 22.316472
# 712422  9497.0      NaN        46                 22.316486
#
#         Corrected Longitude (deg)  Heading (true) (deg)  \
# 0                      113.822197             67.939461
# 1                      113.822927             67.851570
# 2                      113.823658             67.763680
# 3                      113.824386             67.675789
# 4                      113.825114             67.500008
# ...                           ...                   ...
# 712418                 113.914962             75.234383
# 712419                 113.915199             77.695320
# 712420                 113.915433             80.683601
# 712421                 113.915666             83.759773
# 712422                 113.915898             86.660164
#
#         Wind Direction (true) (deg)  Wind Speed (knots)  \
# 0                         23.906250              10.000
# 1                         19.687500              10.000
# 2                         19.687500              10.000
# 3                         15.468750              10.000
# 4                         15.468750              11.000
# ...                             ...                 ...
# 712418                   267.890625               8.250
# 712419                   265.078125               6.750
# 712420                   269.296875               5.500
# 712421                   264.375000               4.625
# 712422                   267.890625               8.250
#
#         Airspeed (calibrated; 1 or Only) (knots)  \
# 0                                        160.000
# 1                                        160.750
# 2                                        161.000
# 3                                        159.500
# 4                                        159.750
# ...                                          ...
# 712418                                    47.250
# 712419                                    48.250
# 712420                                    46.625
# 712421                                    42.250
# 712422                                    42.375
#
#         Baro-Corrected Altitude (ft)  ...  \
# 0                                NaN  ...
# 1                             1526.0  ...
# 2                                NaN  ...
# 3                                NaN  ...
# 4                                NaN  ...
# ...                              ...  ...
# 712418                          61.0  ...
# 712419                          60.0  ...
# 712420                          61.0  ...
# 712421                          61.0  ...
# 712422                          58.0  ...
#
#         Angle of Attack (Corrected) (LH or only) (deg)  \
# 0                                             5.806813
# 1                                             5.611826
# 2                                             6.085366
# 3                                             6.057511
# 4                                             6.085366
# ...                                                ...
# 712418                                        0.175781
# 712419                                        0.087891
# 712420                                        0.439453
# 712421                                        0.307617
# 712422                                        0.175781
#
#         Pitch Attitude (Capt or Only) (deg)  Airport and Runway (Landing)  \
# 0                                  1.977539                      VHHH 07L
# 1                                  1.977539                      VHHH 07L
# 2                                  2.153320                      VHHH 07L
# 3                                  2.285156                      VHHH 07L
# 4                                  2.416991                      VHHH 07L
# ...                                     ...                           ...
# 712418                            -0.351562                      VHHH 07L
# 712419                            -0.351562                      VHHH 07L
# 712420                            -0.703125                      VHHH 07L
# 712421                            -0.703125                      VHHH 07L
# 712422                            -0.351562                      VHHH 07L
#
#         Date-Time at Touchdown     Filename  adjusted landing time  \
# 0          2020-12-15 06:45:00  1000244.csv    2020-12-15 06:42:24
# 1          2020-12-15 06:45:00  1000244.csv    2020-12-15 06:42:25
# 2          2020-12-15 06:45:00  1000244.csv    2020-12-15 06:42:26
# 3          2020-12-15 06:45:00  1000244.csv    2020-12-15 06:42:27
# 4          2020-12-15 06:45:00  1000244.csv    2020-12-15 06:42:28
# ...                        ...          ...                    ...
# 712418     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:56
# 712419     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:57
# 712420     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:58
# 712421     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:59
# 712422     2019-12-27 06:14:00   999942.csv    2019-12-27 06:14:00
#
#        Angle of Attack (Best Available) (deg) 15 knots at the point of GA  \
# 0                                         NaN                        True
# 1                                         NaN                        True
# 2                                         NaN                        True
# 3                                         NaN                        True
# 4                                         NaN                        True
# ...                                       ...                         ...
# 712418                                    NaN                        True
# 712419                                    NaN                        True
# 712420                                    NaN                        True
# 712421                                    NaN                        True
# 712422                                    NaN                        True
#
#        BOOL Angle of Attack (Indicated) (LH or only) (deg)  label
# 0                                                    True   False
# 1                                                    True   False
# 2                                                    True   False
# 3                                                    True   False
# 4                                                    True   False
# ...                                                   ...     ...
# 712418                                               True   False
# 712419                                               True   False
# 712420                                               True   False
# 712421                                               True   False
# 712422                                               True   False
#
# [712423 rows x 24 columns]

# %%
result_combined_df = pd.concat([combined_df_1, combined_df_2, combined_df_3], ignore_index=True)
result_combined_df
# Out:
#          Offset  UTC time  Airframe  Corrected Latitude (deg)  \
# 0       59652.0  21:24:33       124                 22.272130
# 1       59653.0  21:24:34       124                 22.272365
# 2       59654.0  21:24:35       124                 22.272597
# 3       59655.0  21:24:36       124                 22.272829
# 4       59656.0  21:24:37       124                 22.273049
# ...         ...       ...       ...                       ...
# 754548   9493.0       NaN        46                 22.316359
# 754549   9494.0       NaN        46                 22.316406
# 754550   9495.0   6:14:50        46                 22.316439
# 754551   9496.0   6:14:50        46                 22.316472
# 754552   9497.0       NaN        46                 22.316486
#
#         Corrected Longitude (deg)  Heading (true) (deg)  \
# 0                      113.824093             73.448812
# 1                      113.824795             73.975996
# 2                      113.825490             73.624292
# 3                      113.826185             72.921017
# 4                      113.826884             72.745088
# ...                           ...                   ...
# 754548                 113.914962             75.234383
# 754549                 113.915199             77.695320
# 754550                 113.915433             80.683601
# 754551                 113.915666             83.759773
# 754552                 113.915898             86.660164
#
#         Wind Direction (true) (deg)  Wind Speed (knots)  \
# 0                        161.542923               4.000
# 1                         92.109352               6.000
# 2                         98.789040               8.000
# 3                        123.222626               5.000
# 4                        112.939423               2.000
# ...                             ...                 ...
# 754548                   267.890625               8.250
# 754549                   265.078125               6.750
# 754550                   269.296875               5.500
# 754551                   264.375000               4.625
# 754552                   267.890625               8.250
#
#         Airspeed (calibrated; 1 or Only) (knots)  \
# 0                                        149.000
# 1                                        149.000
# 2                                        149.500
# 3                                        144.000
# 4                                        145.000
# ...                                          ...
# 754548                                    47.250
# 754549                                    48.250
# 754550                                    46.625
# 754551                                    42.250
# 754552                                    42.375
#
#         Baro-Corrected Altitude (ft)  ...  \
# 0                             1444.0  ...
# 1                             1440.0  ...
# 2                             1424.0  ...
# 3                             1412.0  ...
# 4                             1400.0  ...
# ...                              ...  ...
# 754548                          61.0  ...
# 754549                          60.0  ...
# 754550                          61.0  ...
# 754551                          61.0  ...
# 754552                          58.0  ...
#
#         Pitch Attitude (Capt or Only) (deg)  Airport and Runway (Landing)  \
# 0                                  1.582032                      VHHH 07R
# 1                                  2.109375                      VHHH 07R
# 2                                  1.933594                      VHHH 07R
# 3                                  1.582032                      VHHH 07R
# 4                                  1.582032                      VHHH 07R
# ...                                     ...                           ...
# 754548                            -0.351562                      VHHH 07L
# 754549                            -0.351562                      VHHH 07L
# 754550                            -0.703125                      VHHH 07L
# 754551                            -0.703125                      VHHH 07L
# 754552                            -0.351562                      VHHH 07L
#
#         Date-Time at Touchdown     Filename  adjusted landing time  \
# 0          2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:23
# 1          2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:24
# 2          2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:25
# 3          2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:26
# 4          2018-04-20 21:42:00  1103799.csv    2018-04-20 21:38:27
# ...                        ...          ...                    ...
# 754548     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:56
# 754549     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:57
# 754550     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:58
# 754551     2019-12-27 06:14:00   999942.csv    2019-12-27 06:13:59
# 754552     2019-12-27 06:14:00   999942.csv    2019-12-27 06:14:00
#
#         Angle of Attack (Best Available) (deg)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 754548                                     NaN
# 754549                                     NaN
# 754550                                     NaN
# 754551                                     NaN
# 754552                                     NaN
#
#        predictive or reactive wind shear warning  \
# 0                                           True
# 1                                           True
# 2                                           True
# 3                                           True
# 4                                           True
# ...                                          ...
# 754548                                       NaN
# 754549                                       NaN
# 754550                                       NaN
# 754551                                       NaN
# 754552                                       NaN
#
#        BOOL Angle of Attack (Indicated) (LH or only) (deg)  label  \
# 0                                                    True    True
# 1                                                    True    True
# 2                                                    True    True
# 3                                                    True    True
# 4                                                    True    True
# ...                                                   ...     ...
# 754548                                               True   False
# 754549                                               True   False
# 754550                                               True   False
# 754551                                               True   False
# 754552                                               True   False
#
#        15 knots at the point of GA
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 754548                        True
# 754549                        True
# 754550                        True
# 754551                        True
# 754552                        True
#
# [754553 rows x 25 columns]

# %%
method_1_path = r'C:\Users\User\Desktop\Final Year Project\Code\Processed_CX\04_Method_1_Raw_Data'
result_combined_df.to_excel(fr"{method_1_path}\Method_1_Raw_Data.xlsx", index=False)
